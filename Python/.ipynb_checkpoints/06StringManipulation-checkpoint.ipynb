# %% [markdown]
# # String Manipultion

# %%
msg = 'Hi welcome Python'

print(msg, type(msg))
# Out:
# Hi welcome Python <class 'str'>

# %%
print(len(msg))
# Out:
# 17

# %%
print(msg[0])
# Out:
# H

# %%
# variableName[ start IndexPosition : End Index Position + 1 ]

print(msg[3:10])
# Out:
# welcome

# %%
course = msg[11:17]

print('Course Name : ', course)
# Out:
# Course Name :  Python

# %% [markdown]
# # Difference between Concatination Operator , and +

# %%
name = 'Sara'

age = 25

print('Name : ', name)

print('Name : '+ name)

print('-------------------------------------')

print('Age : ', age)

print('Age : '+ age)
# Out:
# Name :  Sara
# Name : Sara
# -------------------------------------
# Age :  25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 13
#       9 print('-------------------------------------')
#      11 print('Age : ', age)
# ---> 13 print('Age : '+ age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Positive Index Position

print(msg[3:10])

# Negotive Index Position

print(msg[-14:-7])
# Out:
# welcome
# welcome
